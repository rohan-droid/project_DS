# %%
import numpy as np # for working with arrays and mathematical functon.
import matplotlib.pyplot as plt #to create 2D graphs and plots by using python scripts.
import pandas as pd # to do data science/data analysis and machine learning tasks
import seaborn as sns #to making statistical graphics
from scipy import stats #to perform statistics like chi square test and z test

# %%
# %matplotlib inline # to enable the inline plotting if required

# %%
dfsr=pd.read_csv('311_Service_Requests_from_2010_to_Present.csv')
# to import and read the csv data set named as:=311_Service_Requests_from_2010_to_Present
# Out:
# C:\Users\muktk\AppData\Local\Temp\ipykernel_5860\2230783850.py:1: DtypeWarning: Columns (48,49) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfsr=pd.read_csv('311_Service_Requests_from_2010_to_Present.csv')

# %%
#1.To Understand the dataset find first five rows of dataset
dfsr.head()
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    32310363  12/31/2015 11:59:45 PM  01/01/2016 12:55:15 AM   NYPD
# 1    32309934  12/31/2015 11:59:44 PM  01/01/2016 01:26:57 AM   NYPD
# 2    32309159  12/31/2015 11:59:29 PM  01/01/2016 04:51:03 AM   NYPD
# 3    32305098  12/31/2015 11:57:46 PM  01/01/2016 07:43:13 AM   NYPD
# 4    32306529  12/31/2015 11:56:58 PM  01/01/2016 03:24:42 AM   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type  Incident Zip  \
# 0              Loud Music/Party  Street/Sidewalk       10034.0
# ...

# %%
#1.To Understand the dataset find the no of columns present in dataset 
dfsr.columns
# Out:
# Index(['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Agency Name',
#        'Complaint Type', 'Descriptor', 'Location Type', 'Incident Zip',
#        'Incident Address', 'Street Name', 'Cross Street 1', 'Cross Street 2',
#        'Intersection Street 1', 'Intersection Street 2', 'Address Type',
#        'City', 'Landmark', 'Facility Type', 'Status', 'Due Date',
#        'Resolution Description', 'Resolution Action Updated Date',
#        'Community Board', 'Borough', 'X Coordinate (State Plane)',
#        'Y Coordinate (State Plane)', 'Park Facility Name', 'Park Borough',
#        'School Name', 'School Number', 'School Region', 'School Code',
#        'School Phone Number', 'School Address', 'School City', 'School State',
#        'School Zip', 'School Not Found', 'School or Citywide Complaint',
#        'Vehicle Type', 'Taxi Company Borough', 'Taxi Pick Up Location',
#        'Bridge Highway Name', 'Bridge Highway Direction', 'Road Ramp',
# ...

# %%
#1.To Understand the dataset get info of dataframe
dfsr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 364558 entries, 0 to 364557
# Data columns (total 53 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Unique Key                      364558 non-null  int64
#  1   Created Date                    364558 non-null  object
#  2   Closed Date                     362177 non-null  object
#  3   Agency                          364558 non-null  object
#  4   Agency Name                     364558 non-null  object
#  5   Complaint Type                  364558 non-null  object
#  6   Descriptor                      358057 non-null  object
#  7   Location Type                   364425 non-null  object
#  8   Incident Zip                    361560 non-null  float64
#  9   Incident Address                312859 non-null  object
#  10  Street Name                     312859 non-null  object
#  11  Cross Street 1                  307370 non-null  object
# ...

# %%
#1.1.analyze the shape of dfsr(data frame service request)
np.shape(dfsr)
# Out:
# (364558, 53)

# %%
#1.2.analyze the null value of dfsr(data frame service request)
dfsr.isnull().sum(axis=0)
# Out:
# Unique Key                             0
# Created Date                           0
# Closed Date                         2381
# Agency                                 0
# Agency Name                            0
# Complaint Type                         0
# Descriptor                          6501
# Location Type                        133
# Incident Zip                        2998
# Incident Address                   51699
# Street Name                        51699
# Cross Street 1                     57188
# Cross Street 2                     57805
# Intersection Street 1             313438
# Intersection Street 2             314046
# Address Type                        3252
# City                                2997
# Landmark                          364183
# Facility Type                       2389
# Status                                 0
# Due Date                               3
# Resolution Description                 0
# Resolution Action Updated Date      2402
# ...

# %%
# 2.To Perform basic data exploratory analysis
#2.1.To returns the number of missing values in each column
dfsr.isna().sum()
# Out:
# Unique Key                             0
# Created Date                           0
# Closed Date                         2381
# Agency                                 0
# Agency Name                            0
# Complaint Type                         0
# Descriptor                          6501
# Location Type                        133
# Incident Zip                        2998
# Incident Address                   51699
# Street Name                        51699
# Cross Street 1                     57188
# Cross Street 2                     57805
# Intersection Street 1             313438
# Intersection Street 2             314046
# Address Type                        3252
# City                                2997
# Landmark                          364183
# Facility Type                       2389
# Status                                 0
# Due Date                               3
# Resolution Description                 0
# Resolution Action Updated Date      2402
# ...

# %%
#2.1complaint type
dfsr['Complaint Type'].value_counts()
# Out:
# Blocked Driveway             100881
# Illegal Parking               92679
# Noise - Street/Sidewalk       51692
# Noise - Commercial            44109
# Derelict Vehicle              21661
# Noise - Vehicle               19352
# Animal Abuse                  10541
# Traffic                        5198
# Homeless Encampment            4879
# Vending                        4192
# Noise - Park                   4109
# Drinking                       1409
# Noise - House of Worship       1070
# Posting Advertisement           681
# Urinating in Public             641
# Bike/Roller/Skate Chronic       478
# Panhandling                     327
# Disorderly Youth                315
# Illegal Fireworks               172
# Graffiti                        157
# Agency Issues                     8
# Squeegee                          4
# Ferry Complaint                   2
# Animal in a Park                  1
# Name: Complaint Type, dtype: int64

# %%
#2.1 complaint description
dfsr['Descriptor'].value_counts()
# Out:
# No Access                         75888
# Loud Music/Party                  69708
# Posted Parking Sign Violation     27200
# Partial Access                    24993
# Loud Talking                      23810
# With License Plate                21661
# Blocked Hydrant                   19989
# Commercial Overnight Parking      14997
# Blocked Sidewalk                  13860
# Car/Truck Music                   11940
# Double Parked Blocking Traffic     7164
# Engine Idling                      5323
# Double Parked Blocking Vehicle     5167
# Neglected                          5131
# Banging/Pounding                   4959
# Car/Truck Horn                     4478
# Congestion/Gridlock                3237
# Other (complaint details)          2489
# In Prohibited Area                 2206
# Overnight Commercial Storage       2102
# Unlicensed                         1986
# Unauthorized Bus Layover           1618
# Truck Route Violation              1125
# ...

# %%
#2.1.To compute a simple cross tabulation between Complaint type and its description 
pd.crosstab(index=dfsr['Complaint Type'],columns=dfsr['Descriptor'])
# Out:
# Descriptor                After Hours - Licensed Est  Animal Waste  \
# Complaint Type
# Agency Issues                                      0             0
# Animal Abuse                                       0             0
# Animal in a Park                                   0             1
# Blocked Driveway                                   0             0
# Derelict Vehicle                                   0             0
# Disorderly Youth                                   0             0
# Drinking                                          93             0
# Ferry Complaint                                    0             0
# Graffiti                                           0             0
# Illegal Parking                                    0             0
# Noise - Commercial                                 0             0
# Noise - House of Worship                           0             0
# Noise - Park                                       0             0
# ...

# %%
#2.2.date converted in datetime format
dfsr['Created Date']=pd.to_datetime(dfsr['Created Date'])
dfsr['Closed Date']=pd.to_datetime(dfsr['Closed Date'])

# %%
#2.2.no of complaint created on particular date 
dfsr['Created Date'].value_counts()
# Out:
# 2015-02-11 22:56:36    3
# 2015-08-15 22:49:03    3
# 2015-06-03 22:16:23    3
# 2015-05-09 21:32:57    3
# 2015-09-10 21:19:51    3
#                       ..
# 2015-09-07 14:12:47    1
# 2015-09-07 14:16:39    1
# 2015-09-07 14:18:47    1
# 2015-09-07 14:19:56    1
# 2015-01-01 00:00:50    1
# Name: Created Date, Length: 362018, dtype: int64

# %%
#2.2.time to take response after complaint register
dfsr['response_time']=dfsr['Closed Date']-dfsr['Created Date']
dfsr['response_time']
# Out:
# 0        0 days 00:55:30
# 1        0 days 01:27:13
# 2        0 days 04:51:34
# 3        0 days 07:45:27
# 4        0 days 03:27:44
#                ...
# 364553   0 days 10:17:47
# 364554   0 days 02:20:34
# 364555   0 days 00:19:03
# 364556   0 days 02:40:53
# 364557   0 days 02:47:00
# Name: response_time, Length: 364558, dtype: timedelta64[ns]

# %%
#2.2.no of days to take response after complaint register
dfsr['response_days']=dfsr['response_time']/np.timedelta64(1,'D')

# %%
dfsr['response_days']
# Out:
# 0         0.038542
# 1         0.060567
# 2         0.202477
# 3         0.323229
# 4         0.144259
#             ...
# 364553    0.429016
# 364554    0.097616
# 364555    0.013229
# 364556    0.111725
# 364557    0.115972
# Name: response_days, Length: 364558, dtype: float64

# %%
#2.2.no of hours to take response after complaint register
dfsr['response_hours']=dfsr['response_time']/np.timedelta64(1,'h')
dfsr['response_hours']
# Out:
# 0          0.925000
# 1          1.453611
# 2          4.859444
# 3          7.757500
# 4          3.462222
#             ...
# 364553    10.296389
# 364554     2.342778
# 364555     0.317500
# 364556     2.681389
# 364557     2.783333
# Name: response_hours, Length: 364558, dtype: float64

# %%
#2.2.what agency which take response of registered complaint
dfsr['Agency Name'].value_counts()
# Out:
# New York City Police Department    364548
# Internal Affairs Bureau                 8
# NYPD                                    2
# Name: Agency Name, dtype: int64

# %%
#2.3. location of complaints 
dfsr['Location Type'].value_counts()
# Out:
# Street/Sidewalk               301372
# Store/Commercial               25217
# Club/Bar/Restaurant            21527
# Residential Building/House      8869
# Park/Playground                 4871
# House of Worship                1068
# Residential Building             533
# Highway                          265
# House and Store                  245
# Parking Lot                      167
# Commercial                       108
# Vacant Lot                        95
# Roadway Tunnel                    43
# Subway Station                    40
# Bridge                             2
# Terminal                           1
# Ferry                              1
# Park                               1
# Name: Location Type, dtype: int64

# %%
#2.3.complaints on city wise to plot a chart according to city wise 
dfsr['City'].value_counts()
# Out:
# BROOKLYN               118862
# NEW YORK                77312
# BRONX                   49171
# STATEN ISLAND           15340
# JAMAICA                  8932
# ASTORIA                  7991
# FLUSHING                 7487
# RIDGEWOOD                6392
# CORONA                   5383
# WOODSIDE                 4357
# EAST ELMHURST            3558
# OZONE PARK               3446
# ELMHURST                 3438
# SOUTH RICHMOND HILL      3431
# MASPETH                  3118
# WOODHAVEN                3103
# LONG ISLAND CITY         3028
# SOUTH OZONE PARK         2668
# FRESH MEADOWS            2453
# RICHMOND HILL            2335
# MIDDLE VILLAGE           2291
# QUEENS VILLAGE           2251
# FOREST HILLS             2122
# JACKSON HEIGHTS          2106
# REGO PARK                1807
# BAYSIDE                  1550
# COLLEGE POINT            1544
# FAR ROCKAWAY             1397
# WHITESTONE               1369
# HOLLIS                   1231
# HOWARD BEACH             1144
# ...

# %%
#2.3.to plot a chart according to city wise
sns.countplot(x='City',data=dfsr)
# Out:
# <AxesSubplot:xlabel='City', ylabel='count'>

# %%
#2.3.top ten city according to their complaints 
top_10=dfsr['City'].value_counts()[:10]

# %%
top_10
# Out:
# BROOKLYN         118862
# NEW YORK          77312
# BRONX             49171
# STATEN ISLAND     15340
# JAMAICA            8932
# ASTORIA            7991
# FLUSHING           7487
# RIDGEWOOD          6392
# CORONA             5383
# WOODSIDE           4357
# Name: City, dtype: int64

# %%
#2.3. to plot a bar chart for top ten city according to their complaints 
top_10.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# 2.3.to plot a bar chart for bottom ten city according to their complaints
botm_10=dfsr['City'].value_counts().tail(10)
botm_10
# Out:
# ARVERNE             259
# FLORAL PARK         196
# Long Island City    170
# Woodside            166
# NEW HYDE PARK       129
# CENTRAL PARK        110
# QUEENS               37
# BREEZY POINT         31
# East Elmhurst        30
# Howard Beach          1
# Name: City, dtype: int64

# %%
#2.3.bottom ten values plot graph
botm_10.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#2.4.complaint concentration across Brooklyn
brook_city_complaint=dfsr[dfsr['City']=='BROOKLYN']

# %%
brook_city_complaint['City']
# Out:
# 5         BROOKLYN
# 9         BROOKLYN
# 13        BROOKLYN
# 17        BROOKLYN
# 18        BROOKLYN
#             ...
# 364539    BROOKLYN
# 364541    BROOKLYN
# 364544    BROOKLYN
# 364545    BROOKLYN
# 364546    BROOKLYN
# Name: City, Length: 118862, dtype: object

# %%
dfsr.columns
# Out:
# Index(['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Agency Name',
#        'Complaint Type', 'Descriptor', 'Location Type', 'Incident Zip',
#        'Incident Address', 'Street Name', 'Cross Street 1', 'Cross Street 2',
#        'Intersection Street 1', 'Intersection Street 2', 'Address Type',
#        'City', 'Landmark', 'Facility Type', 'Status', 'Due Date',
#        'Resolution Description', 'Resolution Action Updated Date',
#        'Community Board', 'Borough', 'X Coordinate (State Plane)',
#        'Y Coordinate (State Plane)', 'Park Facility Name', 'Park Borough',
#        'School Name', 'School Number', 'School Region', 'School Code',
#        'School Phone Number', 'School Address', 'School City', 'School State',
#        'School Zip', 'School Not Found', 'School or Citywide Complaint',
#        'Vehicle Type', 'Taxi Company Borough', 'Taxi Pick Up Location',
#        'Bridge Highway Name', 'Bridge Highway Direction', 'Road Ramp',
# ...

# %%
# 2.4.to plot a scatter plot of brooklyn city complaints according to *longitude and latitude* of brooklyn city
brook_city_complaint[['Latitude','Longitude']].plot(kind='scatter',x='Latitude',y='Longitude')
# Out:
# <AxesSubplot:xlabel='Latitude', ylabel='Longitude'>

# %%
#2.4. to plot a hexbin plot of brooklyn city complaints according to *longitude and latitude* of brooklyn city
brook_city_complaint.plot(kind='hexbin',x='Longitude',y='Latitude',gridsize=50,colormap='jet',mincnt=1)
# Out:
# <AxesSubplot:xlabel='Longitude', ylabel='Latitude'>

# %%
#2.4.to plot a scatter plot of brooklyn city complaints according to 'X Coordinate (State Plane)' and
#'Y Coordinate (State Plane)' of brooklyn city
brook_city_complaint[['X Coordinate (State Plane)',
                      'Y Coordinate (State Plane)']].plot(kind='scatter'
                                                          ,x='X Coordinate (State Plane)',
                                                          y='Y Coordinate (State Plane)')
# Out:
# <AxesSubplot:xlabel='X Coordinate (State Plane)', ylabel='Y Coordinate (State Plane)'>

# %%
#2.4.to plot a hexbin plot of brooklyn city complaints according to *'X Coordinate (State Plane)'
#and 'Y Coordinate (State Plane)'* of brooklyn city
brook_city_complaint.plot(kind='hexbin',x='X Coordinate (State Plane)',y='Y Coordinate (State Plane)'
                          ,gridsize=50,colormap='jet',mincnt=1)
# Out:
# <AxesSubplot:xlabel='X Coordinate (State Plane)', ylabel='Y Coordinate (State Plane)'>

# %%
#3.Find major types of complaints:
# 3.1.to Plot a bar graph of count vs. complaint types
dfsr['Complaint Type']
# Out:
# 0         Noise - Street/Sidewalk
# 1                Blocked Driveway
# 2                Blocked Driveway
# 3                 Illegal Parking
# 4                 Illegal Parking
#                    ...
# 364553            Illegal Parking
# 364554            Noise - Vehicle
# 364555    Noise - Street/Sidewalk
# 364556           Blocked Driveway
# 364557           Blocked Driveway
# Name: Complaint Type, Length: 364558, dtype: object

# %%
# 3.Major types of complaints:
comp_type=dfsr['Complaint Type'].value_counts()

# %%
#3.major types of complaints 
comp_type
# Out:
# Blocked Driveway             100881
# Illegal Parking               92679
# Noise - Street/Sidewalk       51692
# Noise - Commercial            44109
# Derelict Vehicle              21661
# Noise - Vehicle               19352
# Animal Abuse                  10541
# Traffic                        5198
# Homeless Encampment            4879
# Vending                        4192
# Noise - Park                   4109
# Drinking                       1409
# Noise - House of Worship       1070
# Posting Advertisement           681
# Urinating in Public             641
# Bike/Roller/Skate Chronic       478
# Panhandling                     327
# Disorderly Youth                315
# Illegal Fireworks               172
# Graffiti                        157
# Agency Issues                     8
# Squeegee                          4
# Ferry Complaint                   2
# Animal in a Park                  1
# Name: Complaint Type, dtype: int64

# %%
# 3.1Bar graph of count vs. complaint types
comp_type.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#3.2.To Find the top 10 types of complaints
comp_type[:10]
# Out:
# Blocked Driveway           100881
# Illegal Parking             92679
# Noise - Street/Sidewalk     51692
# Noise - Commercial          44109
# Derelict Vehicle            21661
# Noise - Vehicle             19352
# Animal Abuse                10541
# Traffic                      5198
# Homeless Encampment          4879
# Vending                      4192
# Name: Complaint Type, dtype: int64

# %%
# 3.3.To Display the types of complaints in each city in a seperate dataset
city_cnt=dfsr.groupby(['City','Complaint Type']).size()
city_cnt
# Out:
# City      Complaint Type
# ARVERNE   Animal Abuse                46
#           Blocked Driveway            50
#           Derelict Vehicle            32
#           Disorderly Youth             2
#           Drinking                     1
#                                     ...
# Woodside  Blocked Driveway            27
#           Derelict Vehicle             8
#           Illegal Parking            124
#           Noise - Commercial           2
#           Noise - Street/Sidewalk      5
# Length: 777, dtype: int64

# %%
#3.3 To Display the types of complaints in each city in a seperate dataset
type(city_cnt)
# Out:
# pandas.core.series.Series

# %%
#3.3 To Display the types of complaints in each city in a seperate dataset
city_cnt.index
# Out:
# MultiIndex([( 'ARVERNE',             'Animal Abuse'),
#             ( 'ARVERNE',         'Blocked Driveway'),
#             ( 'ARVERNE',         'Derelict Vehicle'),
#             ( 'ARVERNE',         'Disorderly Youth'),
#             ( 'ARVERNE',                 'Drinking'),
#             ( 'ARVERNE',                 'Graffiti'),
#             ( 'ARVERNE',      'Homeless Encampment'),
#             ( 'ARVERNE',          'Illegal Parking'),
#             ( 'ARVERNE',       'Noise - Commercial'),
#             ( 'ARVERNE', 'Noise - House of Worship'),
#             ...
#             ('WOODSIDE',  'Noise - Street/Sidewalk'),
#             ('WOODSIDE',          'Noise - Vehicle'),
#             ('WOODSIDE',                  'Traffic'),
#             ('WOODSIDE',      'Urinating in Public'),
#             ('WOODSIDE',                  'Vending'),
#             ('Woodside',         'Blocked Driveway'),
#             ('Woodside',         'Derelict Vehicle'),
# ...

# %%
#3.3 To Display the types of complaints in each city in a seperate dataset
city_cnt.unstack()
# Out:
# Complaint Type       Animal Abuse  Blocked Driveway  Derelict Vehicle  \
# City
# ARVERNE                      46.0              50.0              32.0
# ASTORIA                     170.0            3436.0             426.0
# Astoria                       NaN             159.0              14.0
# BAYSIDE                      53.0             514.0             231.0
# BELLEROSE                    15.0             138.0             120.0
# BREEZY POINT                  2.0               3.0               3.0
# BRONX                      1971.0           17063.0            2403.0
# BROOKLYN                   3191.0           36447.0            6259.0
# CAMBRIA HEIGHTS              15.0             177.0             148.0
# CENTRAL PARK                  NaN               NaN               NaN
# COLLEGE POINT                35.0             597.0             223.0
# CORONA                      104.0            3597.0              72.0
# ...

# %%
# 4.To Visualize the major types of complaints in each city
city_comp_type=pd.crosstab(index=dfsr['City'],columns=dfsr['Complaint Type'])

# %%
city_comp_type
# Out:
# Complaint Type       Animal Abuse  Animal in a Park  \
# City
# ARVERNE                        46                 0
# ASTORIA                       170                 0
# Astoria                         0                 0
# BAYSIDE                        53                 0
# BELLEROSE                      15                 0
# BREEZY POINT                    2                 0
# BRONX                        1971                 0
# BROOKLYN                     3191                 0
# CAMBRIA HEIGHTS                15                 0
# CENTRAL PARK                    0                 0
# COLLEGE POINT                  35                 0
# CORONA                        104                 0
# EAST ELMHURST                  85                 0
# ELMHURST                       59                 0
# East Elmhurst                   0                 0
# FAR ROCKAWAY                  111                 0
# FLORAL PARK                     7                 0
# ...

# %%
#4.1.types of complaints
comp_type
# Out:
# Blocked Driveway             100881
# Illegal Parking               92679
# Noise - Street/Sidewalk       51692
# Noise - Commercial            44109
# Derelict Vehicle              21661
# Noise - Vehicle               19352
# Animal Abuse                  10541
# Traffic                        5198
# Homeless Encampment            4879
# Vending                        4192
# Noise - Park                   4109
# Drinking                       1409
# Noise - House of Worship       1070
# Posting Advertisement           681
# Urinating in Public             641
# Bike/Roller/Skate Chronic       478
# Panhandling                     327
# Disorderly Youth                315
# Illegal Fireworks               172
# Graffiti                        157
# Agency Issues                     8
# Squeegee                          4
# Ferry Complaint                   2
# Animal in a Park                  1
# Name: Complaint Type, dtype: int64

# %%
# 5.Check if the average response time across various types of complaints is significantly different
dfsr[['Complaint Type','response_hours']]
# Out:
#                  Complaint Type  response_hours
# 0       Noise - Street/Sidewalk        0.925000
# 1              Blocked Driveway        1.453611
# 2              Blocked Driveway        4.859444
# 3               Illegal Parking        7.757500
# 4               Illegal Parking        3.462222
# ...                         ...             ...
# 364553          Illegal Parking       10.296389
# 364554          Noise - Vehicle        2.342778
# 364555  Noise - Street/Sidewalk        0.317500
# 364556         Blocked Driveway        2.681389
# 364557         Blocked Driveway        2.783333
#
# [364558 rows x 2 columns]

# %%
#5.
dfsr['Complaint Type'].value_counts()
# Out:
# Blocked Driveway             100881
# Illegal Parking               92679
# Noise - Street/Sidewalk       51692
# Noise - Commercial            44109
# Derelict Vehicle              21661
# Noise - Vehicle               19352
# Animal Abuse                  10541
# Traffic                        5198
# Homeless Encampment            4879
# Vending                        4192
# Noise - Park                   4109
# Drinking                       1409
# Noise - House of Worship       1070
# Posting Advertisement           681
# Urinating in Public             641
# Bike/Roller/Skate Chronic       478
# Panhandling                     327
# Disorderly Youth                315
# Illegal Fireworks               172
# Graffiti                        157
# Agency Issues                     8
# Squeegee                          4
# Ferry Complaint                   2
# Animal in a Park                  1
# Name: Complaint Type, dtype: int64

# %%
#6.Identify significant variables by performing a statistical analysis using p-values and (Optional)
#6.Identify significant variables by performing a statistical analysis using chi-square values (Optional)
# h0: the average response time is the same
# ha: the average response time is different
# if alpha is 5% or 0.05
# p value -0.0000000000
#p < alpha, so we will reject the h0
#the average response time across types of complaints is different
# anova will be for a continous variable

# %%
# look at top 5 complaint types and find if the average response time is same or different
df1=dfsr[dfsr['Complaint Type']=='Blocked Driveway']['response_hours'].dropna()
df2=dfsr[dfsr['Complaint Type']=='Illegal Parking']['response_hours'].dropna()
df3=dfsr[dfsr['Complaint Type']=='Noise - Street/Sidewalk']['response_hours'].dropna()
df4=dfsr[dfsr['Complaint Type']=='Noise - Commercial']['response_hours'].dropna()
df5=dfsr[dfsr['Complaint Type']=='Derelict Vehicle']['response_hours'].dropna()

# %%
stats.f_oneway(df1,df2,df3,df4,df5)
# Out:
# F_onewayResult(statistic=2012.0389087633791, pvalue=0.0)

# %%
dfsr['Created Date'].min()
# Out:
# Timestamp('2015-01-01 00:00:50')

# %%
dfsr['Created Date'].max()
# Out:
# Timestamp('2015-12-31 23:59:45')

# %%
dfsr['Created Date'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
dfsr['Created Date'].describe()
# Out:
# C:\Users\muktk\AppData\Local\Temp\ipykernel_5860\3198794844.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   dfsr['Created Date'].describe()
# count                  364558
# unique                 362018
# top       2015-02-11 22:56:36
# freq                        3
# first     2015-01-01 00:00:50
# last      2015-12-31 23:59:45
# Name: Created Date, dtype: object

# %%
dfsr['Create_date1']=dfsr['Created Date'].dt.date

# %%
dfsr['Create_date1'].hist(bins=50)
# Out:
# <AxesSubplot:>
